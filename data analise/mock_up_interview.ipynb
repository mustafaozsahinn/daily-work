# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("sales_082020.csv")
df2= pd.read_csv("currency_rates_082020_EUR.csv")

# %%
#1 - 2

df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# 0                Dresses               NaN      GBP   19.11  2020-08-03
# 1              Outerwear  Adidas Originals      GBP   15.92  2020-08-09
# 2            Tops - Mens               NaN      GBP    6.37  2020-08-07
# 3            Tops - Mens          Berghaus      GBP   25.27  2020-08-09
# 4       Bottoms - Womens               NaN      GBP    8.90  2020-08-09
# ...                  ...               ...      ...     ...         ...
# 237666  Bottoms - Womens               NaN      GBP   17.11  2020-08-06
# 237667              Home               NaN      USD   69.00  2020-08-05
# 237668             Other               NaN      GBP   58.28  2020-08-05
# 237669             Shoes               NaN      GBP    9.46  2020-08-05
# 237670             Other               NaN      USD  160.76  2020-08-06
#
# [237671 rows x 10 columns]

# %%
df2
# Out:
#     currency       date    rate
# 0        EUR   8/1/2020  1.0000
# 1        EUR   8/2/2020  1.0000
# 2        EUR   8/3/2020  1.0000
# 3        EUR   8/4/2020  1.0000
# 4        EUR   8/5/2020  1.0000
# ..       ...        ...     ...
# 215      BRL   8/6/2020  6.3324
# 216      BRL   8/7/2020  6.4111
# 217      BRL   8/8/2020  6.4111
# 218      BRL   8/9/2020  6.4111
# 219      BRL  8/10/2020  6.4351
#
# [220 rows x 3 columns]

# %%
#3

df.seller_id.nunique()
# Out:
# 114227

# %%
#3

df.seller_id.value_counts()
# Out:
# pzsiehl0    703
# wd3rgi3q    525
# j21w87xy    500
# dbm0o9qu    436
# hbtm3tdy    316
#            ...
# b79drc4f      1
# ivtfeqcd      1
# uvfzdgb4      1
# pbrox97s      1
# 0au7baxi      1
# Name: seller_id, Length: 114227, dtype: int64

# %%
#4

df = df.merge(df2, on = "currency")
df
# Out:
#            buyer_id buyer_country seller_id seller_country  product_code  \
# 0        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 2        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 3        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 4        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# ...             ...           ...       ...            ...           ...
# 2376705  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376706  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376707  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376708  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376709  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
#
#                  category            brand currency  price      date_x  \
# 0                 Dresses              NaN      GBP  19.11  2020-08-03
# 1                 Dresses              NaN      GBP  19.11  2020-08-03
# 2                 Dresses              NaN      GBP  19.11  2020-08-03
# 3                 Dresses              NaN      GBP  19.11  2020-08-03
# 4                 Dresses              NaN      GBP  19.11  2020-08-03
# ...                   ...              ...      ...    ...         ...
# 2376705  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
# 2376706  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
# 2376707  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
# 2376708  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
# 2376709  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
#
#             date_y      rate
# 0         8/1/2020  0.900185
# 1         8/2/2020  0.899325
# 2         8/3/2020  0.899350
# 3         8/4/2020  0.902815
# 4         8/5/2020  0.904500
# ...            ...       ...
# 2376705   8/6/2020  6.332400
# 2376706   8/7/2020  6.411100
# 2376707   8/8/2020  6.411100
# 2376708   8/9/2020  6.411100
# 2376709  8/10/2020  6.435100
#
# [2376710 rows x 12 columns]

# %%
#4

df["EUR"] = df["price"] / df["rate"]
df
# Out:
#            buyer_id buyer_country seller_id seller_country  product_code  \
# 0        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 2        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 3        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 4        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# ...             ...           ...       ...            ...           ...
# 2376705  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376706  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376707  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376708  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376709  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
#
#                  category            brand currency  price      date_x  \
# 0                 Dresses              NaN      GBP  19.11  2020-08-03
# 1                 Dresses              NaN      GBP  19.11  2020-08-03
# 2                 Dresses              NaN      GBP  19.11  2020-08-03
# 3                 Dresses              NaN      GBP  19.11  2020-08-03
# 4                 Dresses              NaN      GBP  19.11  2020-08-03
# ...                   ...              ...      ...    ...         ...
# 2376705  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
# 2376706  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
# 2376707  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
# 2376708  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
# 2376709  Bottoms - Womens  Brandy Melville      BRL  34.92  2020-08-06
#
#             date_y      rate        EUR
# 0         8/1/2020  0.900185  21.228970
# 1         8/2/2020  0.899325  21.249270
# 2         8/3/2020  0.899350  21.248680
# 3         8/4/2020  0.902815  21.167127
# 4         8/5/2020  0.904500  21.127695
# ...            ...       ...        ...
# 2376705   8/6/2020  6.332400   5.514497
# 2376706   8/7/2020  6.411100   5.446803
# 2376707   8/8/2020  6.411100   5.446803
# 2376708   8/9/2020  6.411100   5.446803
# 2376709  8/10/2020  6.435100   5.426489
#
# [2376710 rows x 13 columns]

# %%
#4 ### burda bulduğum değerde 10 günlük rate 1 gün gibi kabul ettiğim için exact sonuç vermedi ama günü kurtardı.

df.EUR.sum()
# Out:
# 64780059.97931622

# %%
#5

df.brand.value_counts(dropna = False)
# Out:
# NaN                   1183410
# Nike                    95750
# Brandy Melville         50650
# Topshop                 45610
# PrettyLittle Thing      41360
#                        ...
# Duke                       10
# Joseph                     10
# MSGM                       10
# Trina Turk                 10
# KTZ                        10
# Name: brand, Length: 1135, dtype: int64

# %%
#6 ####yanlış

((df.category == "Jewellery") & (df.brand.isna()) | (df.brand == "UNSPECIFIED")).sum()
# Out:
# 135250

# %%
#7

((df.brand.value_counts() >= 35) & (df.brand.value_counts() <= 55)).sum()
# Out:
# 95

# %%
#8

((df.buyer_country == "AU") & (df.category == "Shoes")).sum()
# Out:
# 6580

# %%
#9

df.groupby("brand")[["price"]].mean().sort_values(by = "price", ascending = False)
# Out:
#                              price
# brand
# Goyard                  339.363333
# Loewe                   302.043333
# Loeffler Randall        244.840000
# Craig Green             239.940000
# Walter Van Beirendonck  216.180000
# ...                            ...
# MUA                       4.686667
# Max Factor                3.911667
# Bronica                   3.786000
# 360 Cashmere              1.120000
# 36572                     1.120000
#
# [1134 rows x 1 columns]

# %%
#11

US = df[df.seller_country == "US"]
US[US.buyer_country == "US"][["EUR"]].sum() / US[["EUR"]].sum()
# Out:
# EUR    0.9597
# dtype: float64
